# %% [markdown]
# <a href="https://colab.research.google.com/github/swaroopgelye/Data_Science_lab_SE_A15/blob/main/Experiment_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Movie Recommendation System
#
# This notebook aims to develop a model that predicts user ratings for movies and classifies them into high or low ratings. We will use the provided movie, rating, link, genome_tags, tag, and genome_scores CSV files.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the datasets
movies_df = pd.read_csv('/content/movie.csv')
ratings_df = pd.read_csv('/content/rating.csv')
links_df = pd.read_csv('/content/link.csv')
genome_tags_df = pd.read_csv('/content/genome_tags.csv')
tags_df = pd.read_csv('/content/tag.csv')
genome_scores_df = pd.read_csv('/content/genome_scores.csv')

# Display the first 5 rows of each DataFrame
print('Movies DataFrame:')
display(movies_df.head())

print('\nRatings DataFrame:')
display(ratings_df.head())

print('\nLinks DataFrame:')
display(links_df.head())

print('\nGenome Tags DataFrame:')
display(genome_tags_df.head())

print('\nTags DataFrame:')
display(tags_df.head())

print('\nGenome Scores DataFrame:')
display(genome_scores_df.head())
# Out:
# Movies DataFrame:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# Ratings DataFrame:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40
# Links DataFrame:
#    movieId  imdbId   tmdbId
# ...
